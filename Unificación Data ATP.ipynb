# %% [markdown]
# <img src="https://www.unir.net/wp-content/uploads/2019/11/Unir_2021_logo.svg" width="240" height="240" align="right"/>

# %% [markdown]
# <center><h1>Unificación de datasets</header1></center>

# %% [markdown]
# Presentado por: Nathalia Marcela Martinez Vargas  <br>
# Fecha: 4/12/2024

# %% [markdown]
# ## Unificación de datasets

# %% [markdown]
# Se unifican los diferentes datasets desde 2010 hasta 2024 para ATP y para WTA

# %% [markdown]
# ### Instalación de librerias

# %%
# !pip install pandas

# %% [markdown]
# ### Importación de librerias

# %%
import pandas as pd

# %% [markdown]
# Se extraen los dataset de los diferentes años del repositorio en github para posteriormente unificarlos en uno solo, sin embargo, aquí se explorarán cada uno para tener un mapa general del comportamiento de los datos año por año, esto se realiza con el objetivo de encontrar aquellas variables que sean significativas para el estudio y que permitan identificar patrones clave que influyen en el rendimiento deportivo.
#
# Se tiene en cuenta que estos datasets son de un límite temporal desde 2010 hasta 2024 en donde la temporada ya se encuentra finalizada. Además, estos datos son para el circuito masculino.

# %%
# ---- Data 2024 ----
url1 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2024.csv'
df1 = pd.read_csv(url1, sep=';')
df1
# Out:
#       ATP  Location              Tournament        Date       Series    Court  \
# 0       1  Brisbane  Brisbane International  31/12/2023       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International  31/12/2023       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International   1/01/2024       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International   1/01/2024       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International   1/01/2024       ATP250  Outdoor
# ...   ...       ...                     ...         ...          ...      ...
# 2698   65     Turin             Masters Cup  15/11/2024  Masters Cup   Indoor
# 2699   65     Turin             Masters Cup  15/11/2024  Masters Cup   Indoor
# 2700   65     Turin             Masters Cup  16/11/2024  Masters Cup   Indoor
# 2701   65     Turin             Masters Cup  16/11/2024  Masters Cup   Indoor
# 2702   65     Turin             Masters Cup  17/11/2024  Masters Cup   Indoor
#
# ...

# %%
# ---- Data 2023 ----
url2 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2023.csv'
df2 = pd.read_csv(url2, sep=';')
df2
# Out:
#       ATP  Location                Tournament        Date       Series  \
# 0       1  Adelaide  Adelaide International 1   1/01/2023       ATP250
# 1       1  Adelaide  Adelaide International 1   1/01/2023       ATP250
# 2       1  Adelaide  Adelaide International 1   2/01/2023       ATP250
# 3       1  Adelaide  Adelaide International 1   2/01/2023       ATP250
# 4       1  Adelaide  Adelaide International 1   2/01/2023       ATP250
# ...   ...       ...                       ...         ...          ...
# 2698   64     Turin               Masters Cup  17/11/2023  Masters Cup
# 2699   64     Turin               Masters Cup  17/11/2023  Masters Cup
# 2700   64     Turin               Masters Cup  18/11/2023  Masters Cup
# 2701   64     Turin               Masters Cup  18/11/2023  Masters Cup
# 2702   64     Turin               Masters Cup  19/11/2023  Masters Cup
#
#         Court Surface        Round  Best of         Winner  ... Lsets  \
# ...

# %%
# ---- Data 2022 ----
url3 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2022.csv'
df3 = pd.read_csv(url3, sep=';')
df3
# Out:
#       ATP  Location                Tournament        Date       Series  \
# 0       1  Adelaide  Adelaide International 1   3/01/2022       ATP250
# 1       1  Adelaide  Adelaide International 1   3/01/2022       ATP250
# 2       1  Adelaide  Adelaide International 1   3/01/2022       ATP250
# 3       1  Adelaide  Adelaide International 1   3/01/2022       ATP250
# 4       1  Adelaide  Adelaide International 1   4/01/2022       ATP250
# ...   ...       ...                       ...         ...          ...
# 2627   68     Turin               Masters Cup  18/11/2022  Masters Cup
# 2628   68     Turin               Masters Cup  18/11/2022  Masters Cup
# 2629   68     Turin               Masters Cup  19/11/2022  Masters Cup
# 2630   68     Turin               Masters Cup  19/11/2022  Masters Cup
# 2631   68     Turin               Masters Cup  20/11/2022  Masters Cup
#
#         Court Surface        Round  Best of       Winner  ... Lsets  \
# ...

# %%
# ---- Data 2021 ----
url4 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2021.csv'
df4 = pd.read_csv(url4, sep=';')
df4
# Out:
#       ATP Location    Tournament        Date       Series   Court Surface  \
# 0       1  Antalya  Antalya Open   7/01/2021       ATP250  Indoor    Hard
# 1       1  Antalya  Antalya Open   7/01/2021       ATP250  Indoor    Hard
# 2       1  Antalya  Antalya Open   7/01/2021       ATP250  Indoor    Hard
# 3       1  Antalya  Antalya Open   7/01/2021       ATP250  Indoor    Hard
# 4       1  Antalya  Antalya Open   7/01/2021       ATP250  Indoor    Hard
# ...   ...      ...           ...         ...          ...     ...     ...
# 2484   61    Turin   Masters Cup  19/11/2021  Masters Cup  Indoor    Hard
# 2485   61    Turin   Masters Cup  19/11/2021  Masters Cup  Indoor    Hard
# 2486   61    Turin   Masters Cup  20/11/2021  Masters Cup  Indoor    Hard
# 2487   61    Turin   Masters Cup  20/11/2021  Masters Cup  Indoor    Hard
# 2488   61    Turin   Masters Cup  21/11/2021  Masters Cup  Indoor    Hard
#
#             Round  Best of           Winner  ... Lsets    Comment  B365W  \
# ...

# %%
# ---- Data 2020 ----
url5 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2020.csv'
df5 = pd.read_csv(url5, sep=';')
df5
# Out:
#       ATP Location              Tournament        Date       Series    Court  \
# 0       1     Doha  Qatar Exxon Mobil Open   6/01/2020       ATP250  Outdoor
# 1       1     Doha  Qatar Exxon Mobil Open   6/01/2020       ATP250  Outdoor
# 2       1     Doha  Qatar Exxon Mobil Open   6/01/2020       ATP250  Outdoor
# 3       1     Doha  Qatar Exxon Mobil Open   6/01/2020       ATP250  Outdoor
# 4       1     Doha  Qatar Exxon Mobil Open   6/01/2020       ATP250  Outdoor
# ...   ...      ...                     ...         ...          ...      ...
# 1262   32   London             Masters Cup  20/11/2020  Masters Cup   Indoor
# 1263   32   London             Masters Cup  20/11/2020  Masters Cup   Indoor
# 1264   32   London             Masters Cup  21/11/2020  Masters Cup   Indoor
# 1265   32   London             Masters Cup  21/11/2020  Masters Cup   Indoor
# 1266   32   London             Masters Cup  22/11/2020  Masters Cup   Indoor
#
# ...

# %%
# ---- Data 2019 ----
url6 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2019.csv'
df6 = pd.read_csv(url6, sep=';')
df6
# Out:
#       ATP  Location              Tournament        Date       Series    Court  \
# 0       1  Brisbane  Brisbane International  31/12/2018       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International  31/12/2018       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International  31/12/2018       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International  31/12/2018       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International  31/12/2018       ATP250  Outdoor
# ...   ...       ...                     ...         ...          ...      ...
# 2605   66    London             Masters Cup  15/11/2019  Masters Cup   Indoor
# 2606   66    London             Masters Cup  15/11/2019  Masters Cup   Indoor
# 2607   66    London             Masters Cup  16/11/2019  Masters Cup   Indoor
# 2608   66    London             Masters Cup  16/11/2019  Masters Cup   Indoor
# 2609   66    London             Masters Cup  17/11/2019  Masters Cup   Indoor
#
# ...

# %%
# ---- Data 2018 ----
url7 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2018.csv'
df7 = pd.read_csv(url7, sep=';')
df7
# Out:
#       ATP  Location              Tournament        Date       Series    Court  \
# 0       1  Brisbane  Brisbane International  31/12/2017       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International  31/12/2017       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International   1/01/2018       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International   1/01/2018       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International   1/01/2018       ATP250  Outdoor
# ...   ...       ...                     ...         ...          ...      ...
# 2632   67    London             Masters Cup  16/11/2018  Masters Cup   Indoor
# 2633   67    London             Masters Cup  16/11/2018  Masters Cup   Indoor
# 2634   67    London             Masters Cup  17/11/2018  Masters Cup   Indoor
# 2635   67    London             Masters Cup  17/11/2018  Masters Cup   Indoor
# 2636   67    London             Masters Cup  18/11/2018  Masters Cup   Indoor
#
# ...

# %%
# ---- Data 2017 ----
url8 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2017.csv'
df8 = pd.read_csv(url8, sep=';')
df8
# Out:
#       ATP  Location              Tournament        Date       Series    Court  \
# 0       1  Brisbane  Brisbane International   1/01/2017       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International   2/01/2017       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International   2/01/2017       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International   2/01/2017       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International   2/01/2017       ATP250  Outdoor
# ...   ...       ...                     ...         ...          ...      ...
# 2628   67    London             Masters Cup  17/11/2017  Masters Cup   Indoor
# 2629   67    London             Masters Cup  17/11/2017  Masters Cup   Indoor
# 2630   67    London             Masters Cup  18/11/2017  Masters Cup   Indoor
# 2631   67    London             Masters Cup  18/11/2017  Masters Cup   Indoor
# 2632   67    London             Masters Cup  19/11/2017  Masters Cup   Indoor
#
# ...

# %%
# ---- Data 2016 ----
url9 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2016.csv'
df9 = pd.read_csv(url9, sep=';')
df9
# Out:
#       ATP  Location              Tournament        Date       Series    Court  \
# 0       1  Brisbane  Brisbane International   4/01/2016       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International   4/01/2016       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International   4/01/2016       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International   4/01/2016       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International   5/01/2016       ATP250  Outdoor
# ...   ...       ...                     ...         ...          ...      ...
# 2621   66    London             Masters Cup  18/11/2016  Masters Cup   Indoor
# 2622   66    London             Masters Cup  18/11/2016  Masters Cup   Indoor
# 2623   66    London             Masters Cup  19/11/2016  Masters Cup   Indoor
# 2624   66    London             Masters Cup  19/11/2016  Masters Cup   Indoor
# 2625   66    London             Masters Cup  20/11/2016  Masters Cup   Indoor
#
# ...

# %%
# ---- Data 2015 ----
url10 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2015.csv'
df10 = pd.read_csv(url10, sep=';')
df10
# Out:
#       ATP  Location              Tournament        Date       Series    Court  \
# 0       1  Brisbane  Brisbane International   5/01/2015       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International   5/01/2015       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International   5/01/2015       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International   5/01/2015       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International   6/01/2015       ATP250  Outdoor
# ...   ...       ...                     ...         ...          ...      ...
# 2625   66    London             Masters Cup  20/11/2015  Masters Cup   Indoor
# 2626   66    London             Masters Cup  20/11/2015  Masters Cup   Indoor
# 2627   66    London             Masters Cup  21/11/2015  Masters Cup   Indoor
# 2628   66    London             Masters Cup  21/11/2015  Masters Cup   Indoor
# 2629   66    London             Masters Cup  22/11/2015  Masters Cup   Indoor
#
# ...

# %%
# ---- Data 2014 ----
url11 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2014.csv'
df11 = pd.read_csv(url11, sep=';')
df11
# Out:
#       ATP  Location              Tournament        Date       Series    Court  \
# 0       1  Brisbane  Brisbane International  30/12/2013       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International  30/12/2013       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International  30/12/2013       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International  30/12/2013       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International  30/12/2013       ATP250  Outdoor
# ...   ...       ...                     ...         ...          ...      ...
# 2595   64    London             Masters Cup  14/11/2014  Masters Cup   Indoor
# 2596   64    London             Masters Cup  14/11/2014  Masters Cup   Indoor
# 2597   64    London             Masters Cup  15/11/2014  Masters Cup   Indoor
# 2598   64    London             Masters Cup  15/11/2014  Masters Cup   Indoor
# 2599   64    London             Masters Cup  16/11/2014  Masters Cup   Indoor
#
# ...

# %%
# ---- Data 2013 ----
url12 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2013.csv'
df12 = pd.read_csv(url12, sep=';')
df12
# Out:
#       ATP  Location              Tournament        Date       Series    Court  \
# 0       1  Brisbane  Brisbane International  31/12/2012       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International  31/12/2012       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International  31/12/2012       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International  31/12/2012       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International   1/01/2013       ATP250  Outdoor
# ...   ...       ...                     ...         ...          ...      ...
# 2626   65    London             Masters Cup   9/11/2013  Masters Cup   Indoor
# 2627   65    London             Masters Cup   9/11/2013  Masters Cup   Indoor
# 2628   65    London             Masters Cup  10/11/2013  Masters Cup   Indoor
# 2629   65    London             Masters Cup  10/11/2013  Masters Cup   Indoor
# 2630   65    London             Masters Cup  11/11/2013  Masters Cup   Indoor
#
# ...

# %%
# ---- Data 2012 ----
url13 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2012.csv'
df13 = pd.read_csv(url13, sep=';')
df13
# Out:
#       ATP  Location              Tournament        Date       Series    Court  \
# 0       1  Brisbane  Brisbane International   1/01/2012       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International   1/01/2012       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International   2/01/2012       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International   2/01/2012       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International   2/01/2012       ATP250  Outdoor
# ...   ...       ...                     ...         ...          ...      ...
# 2602   65    London             Masters Cup  10/11/2012  Masters Cup   Indoor
# 2603   65    London             Masters Cup  10/11/2012  Masters Cup   Indoor
# 2604   65    London             Masters Cup  11/11/2012  Masters Cup   Indoor
# 2605   65    London             Masters Cup  11/11/2012  Masters Cup   Indoor
# 2606   65    London             Masters Cup  12/11/2012  Masters Cup   Indoor
#
# ...

# %%
# ---- Data 2011 ----
url14 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2011.csv'
df14 = pd.read_csv(url14, sep=';')
df14
# Out:
#       ATP  Location              Tournament        Date       Series    Court  \
# 0       1  Brisbane  Brisbane International   2/01/2011       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International   2/01/2011       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International   3/01/2011       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International   3/01/2011       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International   3/01/2011       ATP250  Outdoor
# ...   ...       ...                     ...         ...          ...      ...
# 2670   65    London             Masters Cup  25/11/2011  Masters Cup   Indoor
# 2671   65    London             Masters Cup  25/11/2011  Masters Cup   Indoor
# 2672   65    London             Masters Cup  26/11/2011  Masters Cup   Indoor
# 2673   65    London             Masters Cup  26/11/2011  Masters Cup   Indoor
# 2674   65    London             Masters Cup  27/11/2011  Masters Cup   Indoor
#
# ...

# %%
# ---- Data 2010 ----
url15 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/ATP/2010.csv'
df15 = pd.read_csv(url15, sep=';')
df15
# Out:
#       ATP  Location              Tournament        Date       Series    Court  \
# 0       1  Brisbane  Brisbane International   4/01/2010       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International   4/01/2010       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International   4/01/2010       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International   4/01/2010       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International   4/01/2010       ATP250  Outdoor
# ...   ...       ...                     ...         ...          ...      ...
# 2674   65    London             Masters Cup  26/11/2010  Masters Cup   Indoor
# 2675   65    London             Masters Cup  26/11/2010  Masters Cup   Indoor
# 2676   65    London             Masters Cup  27/11/2010  Masters Cup   Indoor
# 2677   65    London             Masters Cup  27/11/2010  Masters Cup   Indoor
# 2678   65    London             Masters Cup  28/11/2010  Masters Cup   Indoor
#
# ...

# %% [markdown]
# El código que se aplicó, realiza una unión vertical de los DataFrames df1 a df15, combinándolos en un único DataFrame llamado dataFinalATP. Esto es válido ya que todos los DataFrames tienen las siguientes caracteristicas:
#
# - **El mismo número y nombre de columnas:** para que las filas puedan alinearse correctamente.
# - **Datos compatibles en las columnas:** para evitar problemas con tipos de datos.

# %%
# Unión vertical de los datasets
dataFinalATP = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15], ignore_index=True)

# Mostrar el resultado
print(dataFinalATP)
# Out:
#        ATP  Location              Tournament        Date       Series  \
# 0        1  Brisbane  Brisbane International  31/12/2023       ATP250
# 1        1  Brisbane  Brisbane International  31/12/2023       ATP250
# 2        1  Brisbane  Brisbane International   1/01/2024       ATP250
# 3        1  Brisbane  Brisbane International   1/01/2024       ATP250
# 4        1  Brisbane  Brisbane International   1/01/2024       ATP250
# ...    ...       ...                     ...         ...          ...
# 38117   65    London             Masters Cup  26/11/2010  Masters Cup
# 38118   65    London             Masters Cup  26/11/2010  Masters Cup
# 38119   65    London             Masters Cup  27/11/2010  Masters Cup
# 38120   65    London             Masters Cup  27/11/2010  Masters Cup
# 38121   65    London             Masters Cup  28/11/2010  Masters Cup
#
#          Court Surface        Round  Best of         Winner  ...  MaxW  MaxL  \
# ...

# %%
# Guardar el dataset unificado en un archivo CSV
dataFinalATP.to_csv('dataFinalATP.csv', index=False)

print("El dataset unificado se guardó como 'dataFinalATP.csv'.")

dataFinalATP.to_csv('C:/Users/Nathi/Documents/MaestriaLaRioja/TrabajoFinMaster/ATP/dataFinalATP.csv', index=False)
# Out:
# El dataset unificado se guardó como 'dataFinalATP.csv'.
