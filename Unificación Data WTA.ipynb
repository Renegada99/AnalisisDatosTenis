# %% [markdown]
# <img src="https://www.unir.net/wp-content/uploads/2019/11/Unir_2021_logo.svg" width="240" height="240" align="right"/>

# %% [markdown]
# <center><h1>Unificación de datasets WTA</header1></center>

# %% [markdown]
# Presentado por: Nathalia Marcela Martinez Vargas  <br>
# Fecha: 4/12/2024

# %% [markdown]
# Se unifican los diferentes datasets desde 2010 hasta 2024 para WTA

# %% [markdown]
# ### Instalación de librerias

# %%
# !pip install pandas

# %% [markdown]
# ### Importación de librerias

# %%
import pandas as pd

# %% [markdown]
# Se extraen los dataset de los diferentes años del repositorio en github para posteriormente unificarlos en uno solo, sin embargo, aquí se explorarán cada uno para tener un mapa general del comportamiento de los datos año por año, esto se realiza con el objetivo de encontrar aquellas variables que sean significativas para el estudio y que permitan identificar patrones clave que influyen en el rendimiento deportivo.
#
# Se tiene en cuenta que estos datasets son de un límite temporal desde 2010 hasta 2024 en donde la temporada ya se encuentra finalizada. Además, estos datos son para el circuito Femenino.

# %%
# ---- Data 2024 ----
url1 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2024.csv'
df1 = pd.read_csv(url1, sep=';')
df1
# Out:
#       WTA  Location   Tournament        Date                Tier    Court  \
# 0       1  Auckland  ASB Classic  31/12/2023              WTA250  Outdoor
# 1       1  Auckland  ASB Classic   1/01/2024              WTA250  Outdoor
# 2       1  Auckland  ASB Classic   1/01/2024              WTA250  Outdoor
# 3       1  Auckland  ASB Classic   1/01/2024              WTA250  Outdoor
# 4       1  Auckland  ASB Classic   1/01/2024              WTA250  Outdoor
# ...   ...       ...          ...         ...                 ...      ...
# 2485   55    Riyadh   WTA Finals   7/11/2024  Tour Championships  Outdoor
# 2486   55    Riyadh   WTA Finals   7/11/2024  Tour Championships  Outdoor
# 2487   55    Riyadh   WTA Finals   8/11/2024  Tour Championships  Outdoor
# 2488   55    Riyadh   WTA Finals   8/11/2024  Tour Championships  Outdoor
# 2489   55    Riyadh   WTA Finals   9/11/2024  Tour Championships  Outdoor
#
#      Surface        Round  Best of         Winner  ... Lsets    Comment  \
# ...

# %%
# ---- Data 2023 ----
url2 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2023.csv'
df2 = pd.read_csv(url2, sep=';')
df2
# Out:
#       WTA  Location                Tournament       Date                Tier  \
# 0       1  Adelaide  Adelaide International 1  1/01/2023              WTA500
# 1       1  Adelaide  Adelaide International 1  1/01/2023              WTA500
# 2       1  Adelaide  Adelaide International 1  2/01/2023              WTA500
# 3       1  Adelaide  Adelaide International 1  2/01/2023              WTA500
# 4       1  Adelaide  Adelaide International 1  2/01/2023              WTA500
# ...   ...       ...                       ...        ...                 ...
# 2486   57    Cancun                WTA Finals  3/11/2023  Tour Championships
# 2487   57    Cancun                WTA Finals  4/11/2023  Tour Championships
# 2488   57    Cancun                WTA Finals  4/11/2023  Tour Championships
# 2489   57    Cancun                WTA Finals  5/11/2023  Tour Championships
# 2490   57    Cancun                WTA Finals  6/11/2023  Tour Championships
#
# ...

# %%
# ---- Data 2022 ----
url3 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2022.csv'
df3 = pd.read_csv(url3, sep=';')
df3
# Out:
#       WTA    Location                Tournament       Date  \
# 0       1    Adelaide  Adelaide International 1  3/01/2022
# 1       1    Adelaide  Adelaide International 1  3/01/2022
# 2       1    Adelaide  Adelaide International 1  3/01/2022
# 3       1    Adelaide  Adelaide International 1  3/01/2022
# 4       1    Adelaide  Adelaide International 1  3/01/2022
# ...   ...         ...                       ...        ...
# 2364   55  Fort Worth                WTA Finals  5/11/2022
# 2365   55  Fort Worth                WTA Finals  6/11/2022
# 2366   55  Fort Worth                WTA Finals  6/11/2022
# 2367   55  Fort Worth                WTA Finals  7/11/2022
# 2368   55  Fort Worth                WTA Finals  8/11/2022
#
#                     Tier    Court Surface        Round  Best of  \
# 0                 WTA500  Outdoor    Hard    1st Round        3
# 1                 WTA500  Outdoor    Hard    1st Round        3
# ...

# %%
# ---- Data 2021 ----
url4 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2021.csv'
df4 = pd.read_csv(url4, sep=';')
df4
# Out:
#       WTA     Location                         Tournament        Date  \
# 0       1    Abu Dhabi  Abu Dhabi WTA Women's Tennis Open   6/01/2021
# 1       1    Abu Dhabi  Abu Dhabi WTA Women's Tennis Open   6/01/2021
# 2       1    Abu Dhabi  Abu Dhabi WTA Women's Tennis Open   6/01/2021
# 3       1    Abu Dhabi  Abu Dhabi WTA Women's Tennis Open   6/01/2021
# 4       1    Abu Dhabi  Abu Dhabi WTA Women's Tennis Open   6/01/2021
# ...   ...          ...                                ...         ...
# 2442   56  Guadalajara                         WTA Finals  15/11/2021
# 2443   56  Guadalajara                         WTA Finals  16/11/2021
# 2444   56  Guadalajara                         WTA Finals  16/11/2021
# 2445   56  Guadalajara                         WTA Finals  17/11/2021
# 2446   56  Guadalajara                         WTA Finals  18/11/2021
#
#                     Tier    Court Surface        Round  Best of  \
# ...

# %%
# ---- Data 2020 ----
url5 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2020.csv'
df5 = pd.read_csv(url5, sep=';')
df5
# Out:
#       WTA  Location    Tournament        Date           Tier    Court Surface  \
# 0       1  Auckland   ASB Classic   6/01/2020  International  Outdoor    Hard
# 1       1  Auckland   ASB Classic   6/01/2020  International  Outdoor    Hard
# 2       1  Auckland   ASB Classic   6/01/2020  International  Outdoor    Hard
# 3       1  Auckland   ASB Classic   6/01/2020  International  Outdoor    Hard
# 4       1  Auckland   ASB Classic   6/01/2020  International  Outdoor    Hard
# ...   ...       ...           ...         ...            ...      ...     ...
# 1050   23   Ostrava  Ostrava Open  23/10/2020  International   Indoor    Clay
# 1051   23   Ostrava  Ostrava Open  23/10/2020  International   Indoor    Clay
# 1052   23   Ostrava  Ostrava Open  24/10/2020  International   Indoor    Clay
# 1053   23   Ostrava  Ostrava Open  24/10/2020  International   Indoor    Clay
# 1054   23   Ostrava  Ostrava Open  25/10/2020  International   Indoor    Clay
#
# ...

# %%
# ---- Data 2019 ----
url6 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2019.csv'
df6 = pd.read_csv(url6, sep=';')
df6
# Out:
#       WTA  Location   Tournament        Date                Tier    Court  \
# 0       1  Auckland  ASB Classic  31/12/2018       International  Outdoor
# 1       1  Auckland  ASB Classic  31/12/2018       International  Outdoor
# 2       1  Auckland  ASB Classic  31/12/2018       International  Outdoor
# 3       1  Auckland  ASB Classic  31/12/2018       International  Outdoor
# 4       1  Auckland  ASB Classic  31/12/2018       International  Outdoor
# ...   ...       ...          ...         ...                 ...      ...
# 2467   58  Shenzhen   WTA Finals   1/11/2019  Tour Championships   Indoor
# 2468   58  Shenzhen   WTA Finals   1/11/2019  Tour Championships   Indoor
# 2469   58  Shenzhen   WTA Finals   2/11/2019  Tour Championships   Indoor
# 2470   58  Shenzhen   WTA Finals   2/11/2019  Tour Championships   Indoor
# 2471   58  Shenzhen   WTA Finals   3/11/2019  Tour Championships   Indoor
#
#      Surface        Round  Best of             Winner  ... Lsets    Comment  \
# ...

# %%
# ---- Data 2018 ----
url7 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2018.csv'
df7 = pd.read_csv(url7, sep=';')
df7
# Out:
#       WTA  Location        Tournament        Date                Tier  \
# 0       1  Auckland       ASB Classic  31/12/2017       International
# 1       1  Auckland       ASB Classic  31/12/2017       International
# 2       1  Auckland       ASB Classic   1/01/2018       International
# 3       1  Auckland       ASB Classic   1/01/2018       International
# 4       1  Auckland       ASB Classic   1/01/2018       International
# ...   ...       ...               ...         ...                 ...
# 2464   59    Zhuhai  WTA Elite Trophy   2/11/2018  Tour Championships
# 2465   59    Zhuhai  WTA Elite Trophy   2/11/2018  Tour Championships
# 2466   59    Zhuhai  WTA Elite Trophy   3/11/2018  Tour Championships
# 2467   59    Zhuhai  WTA Elite Trophy   3/11/2018  Tour Championships
# 2468   59    Zhuhai  WTA Elite Trophy   4/11/2018  Tour Championships
#
#         Court Surface        Round  Best of       Winner  ...   EXW   EXL  \
# ...

# %%
# ---- Data 2017 ----
url8 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2017.csv'
df8 = pd.read_csv(url8, sep=';')
df8
# Out:
#       WTA  Location        Tournament       Date                Tier    Court  \
# 0       1  Auckland       ASB Classic  1/01/2017       International  Outdoor
# 1       1  Auckland       ASB Classic  1/01/2017       International  Outdoor
# 2       1  Auckland       ASB Classic  2/01/2017       International  Outdoor
# 3       1  Auckland       ASB Classic  2/01/2017       International  Outdoor
# 4       1  Auckland       ASB Classic  3/01/2017       International  Outdoor
# ...   ...       ...               ...        ...                 ...      ...
# 2495   59    Zhuhai  WTA Elite Trophy  3/11/2017  Tour Championships   Indoor
# 2496   59    Zhuhai  WTA Elite Trophy  3/11/2017  Tour Championships   Indoor
# 2497   59    Zhuhai  WTA Elite Trophy  4/11/2017  Tour Championships   Indoor
# 2498   59    Zhuhai  WTA Elite Trophy  4/11/2017  Tour Championships   Indoor
# 2499   59    Zhuhai  WTA Elite Trophy  5/11/2017  Tour Championships   Indoor
#
# ...

# %%
# ---- Data 2016 ----
url9 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2016.csv'
df9 = pd.read_csv(url9, sep=';')
df9
# Out:
#       WTA  Location        Tournament       Date                Tier    Court  \
# 0       1  Auckland       ASB Classic  3/01/2016       International  Outdoor
# 1       1  Auckland       ASB Classic  3/01/2016       International  Outdoor
# 2       1  Auckland       ASB Classic  4/01/2016       International  Outdoor
# 3       1  Auckland       ASB Classic  4/01/2016       International  Outdoor
# 4       1  Auckland       ASB Classic  4/01/2016       International  Outdoor
# ...   ...       ...               ...        ...                 ...      ...
# 2517   60    Zhuhai  WTA Elite Trophy  4/11/2016  Tour Championships   Indoor
# 2518   60    Zhuhai  WTA Elite Trophy  4/11/2016  Tour Championships   Indoor
# 2519   60    Zhuhai  WTA Elite Trophy  5/11/2016  Tour Championships   Indoor
# 2520   60    Zhuhai  WTA Elite Trophy  5/11/2016  Tour Championships   Indoor
# 2521   60    Zhuhai  WTA Elite Trophy  6/11/2016  Tour Championships   Indoor
#
# ...

# %%
# ---- Data 2015 ----
url10 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2015.csv'
df10 = pd.read_csv(url10, sep=';')
df10
# Out:
#       WTA  Location        Tournament       Date                Tier    Court  \
# 0       1  Auckland       ASB Classic  4/01/2015       International  Outdoor
# 1       1  Auckland       ASB Classic  4/01/2015       International  Outdoor
# 2       1  Auckland       ASB Classic  5/01/2015       International  Outdoor
# 3       1  Auckland       ASB Classic  5/01/2015       International  Outdoor
# 4       1  Auckland       ASB Classic  5/01/2015       International  Outdoor
# ...   ...       ...               ...        ...                 ...      ...
# 2516   59    Zhuhai  WTA Elite Trophy  6/11/2015  Tour Championships   Indoor
# 2517   59    Zhuhai  WTA Elite Trophy  6/11/2015  Tour Championships   Indoor
# 2518   59    Zhuhai  WTA Elite Trophy  7/11/2015  Tour Championships   Indoor
# 2519   59    Zhuhai  WTA Elite Trophy  7/11/2015  Tour Championships   Indoor
# 2520   59    Zhuhai  WTA Elite Trophy  8/11/2015  Tour Championships   Indoor
#
# ...

# %%
# ---- Data 2014 ----
url11 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2014.csv'
df11 = pd.read_csv(url11, sep=';')
df11
# Out:
#       WTA  Location                                Tournament        Date  \
# 0       1  Auckland                               ASB Classic  30/12/2013
# 1       1  Auckland                               ASB Classic  30/12/2013
# 2       1  Auckland                               ASB Classic  30/12/2013
# 3       1  Auckland                               ASB Classic  30/12/2013
# 4       1  Auckland                               ASB Classic  30/12/2013
# ...   ...       ...                                       ...         ...
# 2471   58     Sofia  Garanti Koza WTA Tournament of Champions  31/10/2014
# 2472   58     Sofia  Garanti Koza WTA Tournament of Champions  31/10/2014
# 2473   58     Sofia  Garanti Koza WTA Tournament of Champions   1/11/2014
# 2474   58     Sofia  Garanti Koza WTA Tournament of Champions   1/11/2014
# 2475   58     Sofia  Garanti Koza WTA Tournament of Champions   2/11/2014
#
#                Tier    Court Surface        Round  Best of         Winner  \
# ...

# %%
# ---- Data 2013 ----
url12 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2013.csv'
df12 = pd.read_csv(url12, sep=';')
df12
# Out:
#       WTA  Location                                Tournament        Date  \
# 0       1  Auckland                               ASB Classic  30/12/2012
# 1       1  Auckland                               ASB Classic  31/12/2012
# 2       1  Auckland                               ASB Classic  31/12/2012
# 3       1  Auckland                               ASB Classic  31/12/2012
# 4       1  Auckland                               ASB Classic  31/12/2012
# ...   ...       ...                                       ...         ...
# 2437   57     Sofia  Garanti Koza WTA Tournament of Champions   1/11/2013
# 2438   57     Sofia  Garanti Koza WTA Tournament of Champions   1/11/2013
# 2439   57     Sofia  Garanti Koza WTA Tournament of Champions   2/11/2013
# 2440   57     Sofia  Garanti Koza WTA Tournament of Champions   2/11/2013
# 2441   57     Sofia  Garanti Koza WTA Tournament of Champions   3/11/2013
#
#                Tier    Court Surface        Round  Best of             Winner  \
# ...

# %%
# ---- Data 2012 ----
url13 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2012.csv'
df13 = pd.read_csv(url13, sep=';')
df13
# Out:
#       WTA  Location                                   Tournament       Date  \
# 0       1  Auckland                                  ASB Classic  2/01/2012
# 1       1  Auckland                                  ASB Classic  2/01/2012
# 2       1  Auckland                                  ASB Classic  2/01/2012
# 3       1  Auckland                                  ASB Classic  2/01/2012
# 4       1  Auckland                                  ASB Classic  2/01/2012
# ...   ...       ...                                          ...        ...
# 2402   56     Sofia  Qatar Airways Tournament of Champions Sofia  2/11/2012
# 2403   56     Sofia  Qatar Airways Tournament of Champions Sofia  2/11/2012
# 2404   56     Sofia  Qatar Airways Tournament of Champions Sofia  3/11/2012
# 2405   56     Sofia  Qatar Airways Tournament of Champions Sofia  3/11/2012
# 2406   56     Sofia  Qatar Airways Tournament of Champions Sofia  4/11/2012
#
# ...

# %%
# ---- Data 2011 ----
url14 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2011.csv'
df14 = pd.read_csv(url14, sep=';')
df14
# Out:
#       WTA  Location                                 Tournament       Date  \
# 0       1  Auckland                                ASB Classic  2/01/2011
# 1       1  Auckland                                ASB Classic  3/01/2011
# 2       1  Auckland                                ASB Classic  3/01/2011
# 3       1  Auckland                                ASB Classic  3/01/2011
# 4       1  Auckland                                ASB Classic  3/01/2011
# ...   ...       ...                                        ...        ...
# 2463   57      Bali  Commonwealth Bank Tournament of Champions  4/11/2011
# 2464   57      Bali  Commonwealth Bank Tournament of Champions  5/11/2011
# 2465   57      Bali  Commonwealth Bank Tournament of Champions  5/11/2011
# 2466   57      Bali  Commonwealth Bank Tournament of Champions  6/11/2011
# 2467   57      Bali  Commonwealth Bank Tournament of Champions  6/11/2011
#
#                Tier    Court Surface          Round  Best of  \
# ...

# %%
# ---- Data 2010 ----
url15 = 'https://raw.githubusercontent.com/Renegada99/AnalisisDatosTenis/refs/heads/main/WTA/2010.csv'
df15 = pd.read_csv(url15, sep=';')
df15
# Out:
#       WTA  Location                                 Tournament       Date  \
# 0       1  Auckland                                ASB Classic  3/01/2010
# 1       1  Auckland                                ASB Classic  4/01/2010
# 2       1  Auckland                                ASB Classic  4/01/2010
# 3       1  Auckland                                ASB Classic  4/01/2010
# 4       1  Auckland                                ASB Classic  4/01/2010
# ...   ...       ...                                        ...        ...
# 2443   57      Bali  Commonwealth Bank Tournament of Champions  5/11/2010
# 2444   57      Bali  Commonwealth Bank Tournament of Champions  6/11/2010
# 2445   57      Bali  Commonwealth Bank Tournament of Champions  6/11/2010
# 2446   57      Bali  Commonwealth Bank Tournament of Champions  7/11/2010
# 2447   57      Bali  Commonwealth Bank Tournament of Champions  7/11/2010
#
#                Tier    Court Surface          Round  Best of         Winner  \
# ...

# %% [markdown]
# El código que se aplicó, realiza una unión vertical de los DataFrames df1 a df15, combinándolos en un único DataFrame llamado dataFinalATP. Esto es válido ya que todos los DataFrames tienen las siguientes caracteristicas:
#
# - **El mismo número y nombre de columnas:** para que las filas puedan alinearse correctamente.
# - **Datos compatibles en las columnas:** para evitar problemas con tipos de datos.

# %%
# Unión vertical de los datasets
dataFinalWTA = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15], ignore_index=True)

# Mostrar el resultado
print(dataFinalWTA)
# Out:
#        WTA  Location                                 Tournament        Date  \
# 0        1  Auckland                                ASB Classic  31/12/2023
# 1        1  Auckland                                ASB Classic   1/01/2024
# 2        1  Auckland                                ASB Classic   1/01/2024
# 3        1  Auckland                                ASB Classic   1/01/2024
# 4        1  Auckland                                ASB Classic   1/01/2024
# ...    ...       ...                                        ...         ...
# 35572   57      Bali  Commonwealth Bank Tournament of Champions   5/11/2010
# 35573   57      Bali  Commonwealth Bank Tournament of Champions   6/11/2010
# 35574   57      Bali  Commonwealth Bank Tournament of Champions   6/11/2010
# 35575   57      Bali  Commonwealth Bank Tournament of Champions   7/11/2010
# 35576   57      Bali  Commonwealth Bank Tournament of Champions   7/11/2010
#
# ...

# %%
# Guardar el dataset unificado en un archivo CSV
dataFinalWTA.to_csv('dataFinalWTA.csv', index=False)

print("El dataset unificado se guardó como 'dataFinalWTA.csv'.")

dataFinalWTA.to_csv('C:/Users/Nathi/Documents/MaestriaLaRioja/TrabajoFinMaster/WTA/dataFinalWTA.csv', index=False)
# Out:
# El dataset unificado se guardó como 'dataFinalWTA.csv'.
